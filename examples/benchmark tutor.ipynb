# %% [markdown]
# # Benhcmark model tutor

# %%
import sys
sys.path.append('..')

import warnings
warnings.filterwarnings('ignore')

import datetime
import time
import random
import string
import os
import json
import random
import string
from pprint import pformat
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)
# logging.debug("test")
# logging.basicConfig(filename='./temp_tutor.log', level=logging.INFO)



# --- Dependencies
import pygmo as pg
import numpy as np
import pandas as pd

from sklearn.model_selection import ParameterGrid
from sklearn import  clone
import sklearn.gaussian_process as gp
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.dummy import DummyRegressor

from src.composite import PredictTutor, ModelsUnion
from src.generator import SamplesGenerator

from src.hypothesis.custom_gp_kernel import KERNEL_MAUNA, KERNEL_SIMPLE, KERNEL_GPML
from src.ploting import plot_mo

# %%
def make_nd_pop(pro, x, y):
    nd_front = pg.fast_non_dominated_sorting(y)[0][0]
    nd_x = np.array(x)[nd_front]
    nd_y = np.array(y)[nd_front]
    t_pop = pg.population(pro)
    for i, p_vector in enumerate(nd_x):
        t_pop.push_back(x=p_vector, f=nd_y[i])
    return t_pop


def tuning_loop(pro, surr_portfolio, n_iter, n_pred=1):
    gen = SamplesGenerator(pro)
    # tutor = make_pipeline(PredictTutor(pro.get_bounds(), portfolio=[grad_uni, lin_uni]))
    tutor = PredictTutor(pro.get_bounds(), portfolio=[gp_sim, grad_uni])

    loop_start = time.time()
    iter_solution = []
    i=0
    while i < 27:
        i=i+1
        logging.info("\n--- {}".format(i))
        X, y = gen.return_X_y()
        tutor.fit(X, y, cv=4)
        propos = tutor.predict(n_pred=1)
        logging.info(propos)

        pred = json.loads(tutor.predict_proba(None).to_json(orient='records'))[0]
        pred['prediction'] = propos
        pred['iteration'] = i
        pred['problem'] = pro.get_name()
        pred['objectives'] = pro.get_nobj()
        pred['feature_dim'] = pro.get_nx()


        gen.update(list(propos), [pro.fitness(p).tolist() for p in propos])

        # ----------------------                                                             Hypervolume
        samples_x, samples_y = gen.return_X_y()
        if 0 in (np.array(samples_x).size, np.array(samples_y).size):
            continue

        try:
            nd_pop = make_nd_pop(pro, np.array(samples_x), np.array(samples_y))
            hypervolume = pg.hypervolume(-nd_pop.get_f()).compute([0]*nd_pop.problem.get_nobj())
            pred['hypervolume'] = hypervolume or None
        except Exception as err:
            pred['error'] = "Hypervolume: {}".format(err)
            iter_solution.append(pred)
            continue

        # ----------------------                                                            Spacing metric
        try:
            dist = pg.crowding_distance(points=nd_pop.get_f())
            not_inf_dist = dist[np.isfinite(dist)]
            mean_dist = np.mean(not_inf_dist)
            space_m = (sum([(mean_dist - d)**2 for d in not_inf_dist]
                           )/(len(not_inf_dist)-1))**(1/2)
            pred["ndf_space"] = space_m
        except Exception as err:
            pred['error'] = "Spacing metric: {}".format(err)
            iter_solution.append(pred)
            continue


        pred["i_time"] = time.time() - loop_start
        iter_solution.append(pred)


    loop = pd.DataFrame(iter_solution)
    loop = loop.drop(['estimator'], axis=1, errors='ignore')
    loop = loop.assign(tutor_id=id(tutor))
    
    
    # File and path to folder
    prefix = loop.iloc[-1].tutor_id
    rel_path = '/{}_tutor_loop_{}.{}.csv'.format(
        pro.get_name(), len(iter_solution), prefix)

#     path = os.path.dirname(os.path.abspath(__file__))

    path = '.'

    # Write results
    print(" Write meta. Path:{}".format(path + rel_path))
    loop.to_csv(path + rel_path, mode='a+', index=False)
    
    X, y = gen.return_X_y()
    return np.array(X), np.array(y)

# %% [markdown]
# # Problem

# %%
# 1
# tea_pot = TpotWrp(generations=2, population_size=10, random_state=42) 
# 2
gp_sim = gp.GaussianProcessRegressor(kernel=KERNEL_MAUNA, alpha=0, n_restarts_optimizer=10, normalize_y=True) 
# 3
grad_uni = ModelsUnion(
    models=[GradientBoostingRegressor(n_estimators=200)],
    split_y=True) 
# 4 
lin_uni = ModelsUnion(models=[LinearRegression()], split_y=True)

# %%
DIM = 2
ID = 4
OBJ = 2

# --- Problem
# udp = pg.wfg(prob_id=ID, dim_dvs=DIM, dim_obj=OBJ, dim_k=OBJ-1)
udp = pg.zdt(prob_id=ID, param=DIM)
pro = pg.problem(udp)
pro.get_bounds()
# Out:
# (array([ 0., -5.]), array([1., 5.]))

# %%
# re = tuning_loop(pro, [gp_sim, grad_uni], 30)

# %%
pd.read_csv("./WFG4_tutor_loop_27.csv").drop(['params hash', 'y_index', 'test_neg_mean_squared_error', 'error'], axis=1).iloc[-1].tutor_id
# Out:
# 140205238229480

# %%
# temp = [{
#     "id": 1111,
#     "sdsd": "lolololo",
#     "go": 12121212213134
# }]

# dt = pd.concat([re, pd.DataFrame(temp)])
# dt

# %%
gp_sim = gp.GaussianProcessRegressor(kernel=KERNEL_MAUNA, alpha=0, n_restarts_optimizer=10, normalize_y=True) 
# 3
grad_uni = ModelsUnion(
    models=[GradientBoostingRegressor(n_estimators=200)],
    split_y=True) 
# 4 
lin_uni = ModelsUnion(models=[LinearRegression()], split_y=True)

gen = SamplesGenerator(pro)
# tutor = make_pipeline(PredictTutor(pro.get_bounds(), portfolio=[grad_uni, lin_uni]))
tutor = PredictTutor(pro.get_bounds(), portfolio=[gp_sim, grad_uni])

loop_start = time.time()
iter_solution = []
i=0
while i < 27:
    i=i+1
    logging.info("\n--- {}".format(i))
    X, y = gen.return_X_y()
    tutor.fit(X, y, cv=4)
    propos = tutor.predict(n=5)
    logging.info(propos)

    pred = json.loads(tutor.predict_proba(None).to_json(orient='records'))[0]
    pred['prediction'] = propos
    pred['iteration'] = i
    pred['problem'] = pro.get_name()
    pred['objectives'] = pro.get_nobj()
    pred['feature_dim'] = pro.get_nx()


    gen.update(list(propos), [pro.fitness(p).tolist() for p in propos])

    # ----------------------                                                             Hypervolume
    samples_x, samples_y = gen.return_X_y()
    if 0 in (np.array(samples_x).size, np.array(samples_y).size):
        continue

    try:
        nd_pop = make_nd_pop(pro, np.array(samples_x), np.array(samples_y))
        hypervolume = pg.hypervolume(-nd_pop.get_f()).compute([0]*nd_pop.problem.get_nobj())
        pred['hypervolume'] = hypervolume or None
    except Exception as err:
        pred['error'] = "Hypervolume: {}".format(err)
        iter_solution.append(pred)
        continue

    # ----------------------                                                            Spacing metric
    try:
        dist = pg.crowding_distance(points=nd_pop.get_f())
        not_inf_dist = dist[np.isfinite(dist)]
        mean_dist = np.mean(not_inf_dist)
        space_m = (sum([(mean_dist - d)**2 for d in not_inf_dist]
                       )/(len(not_inf_dist)-1))**(1/2)
        pred["ndf_space"] = space_m
    except Exception as err:
        pred['error'] = "Spacing metric: {}".format(err)
        iter_solution.append(pred)
        continue


    pred["i_time"] = time.time() - loop_start
    iter_solution.append(pred)


loop = pd.DataFrame(iter_solution)
# loop["loop_time"] = time.time() - loop_start
loop.assign(tutor_id=id(tutor))
# Out:
# INFO:root:
# --- 1
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.5, 0.0], [0.75, -2.5], [0.25, 2.5], [0.375, -1.25], [0.875, 3.75]]
# INFO:root:Initialization data generator
# INFO:root:
# --- 2
# INFO:root:Available 5. At least 8 samples are required
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.625, -3.75], [0.125, 1.25], [0.1875, -1.875], [0.6875, 3.125], [0.9375, -4.375]]
# INFO:root:In dataset add 5 new results
# INFO:root:
# --- 3
# INFO:root:Split dataset. Validation set is 0.25%
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.4375, 0.625], [0.3125, -3.125], [0.8125, 1.875], [0.5625, -0.625], [0.0625, 4.375]]
# INFO:root:In dataset add 5 new results
# INFO:root:
# --- 4
# INFO:root:Split dataset. Validation set is 0.25%
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.09375, -0.3125], [0.59375, 4.6875], [0.84375, -2.8125], [0.34375, 2.1875], [0.46875, -4.0625]]
# INFO:root:In dataset add 5 new results
# INFO:root:
# --- 5
# INFO:root:Split dataset. Validation set is 0.25%
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.96875, 0.9375], [0.71875, -1.5625], [0.21875, 3.4375], [0.15625, -3.4375], [0.65625, 1.5625]]
# INFO:root:In dataset add 5 new results
# INFO:root:
# --- 6
# INFO:root:Split dataset. Validation set is 0.25%
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.90625, -0.9375], [0.40625, 4.0625], [0.28125, -2.1875], [0.78125, 2.8125], [0.53125, -4.6875]]
# INFO:root:In dataset add 5 new results
# INFO:root:
# --- 7
# INFO:root:Split dataset. Validation set is 0.25%
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.03125, 0.3125], [0.046875, -2.34375], [0.546875, 2.65625], [0.796875, -4.84375], [0.296875, 0.15625]]
# INFO:root:In dataset add 5 new results
# INFO:root:
# --- 8
# INFO:root:Split dataset. Validation set is 0.25%
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.421875, -3.59375], [0.921875, 1.40625], [0.671875, -1.09375], [0.171875, 3.90625], [0.234375, -4.21875]]
# INFO:root:In dataset add 5 new results
# INFO:root:
# --- 9
# INFO:root:Split dataset. Validation set is 0.25%
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.734375, 0.78125], [0.984375, -1.71875], [0.484375, 3.28125], [0.359375, -0.46875], [0.859375, 4.53125]]
# INFO:root:In dataset add 5 new results
# INFO:root:
# --- 10
# INFO:root:Split dataset. Validation set is 0.25%
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.609375, -2.96875], [0.109375, 2.03125], [0.078125, -2.65625], [0.578125, 2.34375], [0.828125, -0.15625]]
# INFO:root:In dataset add 5 new results
# INFO:root:
# --- 11
# INFO:root:Split dataset. Validation set is 0.25%
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.328125, 4.84375], [0.453125, -1.40625], [0.953125, 3.59375], [0.703125, -3.90625], [0.203125, 1.09375]]
# INFO:root:In dataset add 5 new results
# INFO:root:
# --- 12
# INFO:root:Split dataset. Validation set is 0.25%
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.140625, -0.78125], [0.640625, 4.21875], [0.890625, -3.28125], [0.390625, 1.71875], [0.265625, -4.53125]]
# INFO:root:In dataset add 5 new results
# INFO:root:
# --- 13
# INFO:root:Split dataset. Validation set is 0.25%
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.765625, 0.46875], [0.515625, -2.03125], [0.015625, 2.96875], [0.0234375, -1.015625], [0.5234375, 3.984375]]
# INFO:root:In dataset add 5 new results
# INFO:root:
# --- 14
# INFO:root:Split dataset. Validation set is 0.25%
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.7734375, -3.515625], [0.2734375, 1.484375], [0.3984375, -4.765625], [0.8984375, 0.234375], [0.6484375, -2.265625]]
# INFO:root:In dataset add 5 new results
# INFO:root:
# --- 15
# INFO:root:Split dataset. Validation set is 0.25%
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.1484375, 2.734375], [0.2109375, -2.890625], [0.7109375, 2.109375], [0.9609375, -0.390625], [0.4609375, 4.609375]]
# INFO:root:In dataset add 5 new results
# INFO:root:
# --- 16
# INFO:root:Split dataset. Validation set is 0.25%
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.3359375, -1.640625], [0.8359375, 3.359375], [0.5859375, -4.140625], [0.0859375, 0.859375], [0.1171875, -3.828125]]
# INFO:root:In dataset add 5 new results
# INFO:root:
# --- 17
# INFO:root:Split dataset. Validation set is 0.25%
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.6171875, 1.171875], [0.8671875, -1.328125], [0.3671875, 3.671875], [0.4921875, -0.078125], [0.9921875, 4.921875]]
# INFO:root:In dataset add 5 new results
# INFO:root:
# --- 18
# INFO:root:Split dataset. Validation set is 0.25%
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.7421875, -2.578125], [0.2421875, 2.421875], [0.1796875, -1.953125], [0.6796875, 3.046875], [0.9296875, -4.453125]]
# INFO:root:In dataset add 5 new results
# INFO:root:
# --- 19
# INFO:root:Split dataset. Validation set is 0.25%
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.4296875, 0.546875], [0.3046875, -3.203125], [0.8046875, 1.796875], [0.5546875, -0.703125], [0.0546875, 4.296875]]
# INFO:root:In dataset add 5 new results
# INFO:root:
# --- 20
# INFO:root:Split dataset. Validation set is 0.25%
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.0390625, -3.671875], [0.5390625, 1.328125], [0.7890625, -1.171875], [0.2890625, 3.828125], [0.4140625, -2.421875]]
# INFO:root:In dataset add 5 new results
# INFO:root:
# --- 21
# INFO:root:Split dataset. Validation set is 0.25%
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.9140625, 2.578125], [0.6640625, -4.921875], [0.1640625, 0.078125], [0.2265625, -0.546875], [0.7265625, 4.453125]]
# INFO:root:In dataset add 5 new results
# INFO:root:
# --- 22
# INFO:root:Split dataset. Validation set is 0.25%
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.9765625, -3.046875], [0.4765625, 1.953125], [0.3515625, -4.296875], [0.8515625, 0.703125], [0.6015625, -1.796875]]
# INFO:root:In dataset add 5 new results
# INFO:root:
# --- 23
# INFO:root:Split dataset. Validation set is 0.25%
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.1015625, 3.203125], [0.0703125, -1.484375], [0.5703125, 3.515625], [0.8203125, -3.984375], [0.3203125, 1.015625]]
# INFO:root:In dataset add 5 new results
# INFO:root:
# --- 24
# INFO:root:Split dataset. Validation set is 0.25%
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.4453125, -2.734375], [0.9453125, 2.265625], [0.6953125, -0.234375], [0.1953125, 4.765625], [0.1328125, -4.609375]]
# INFO:root:In dataset add 5 new results
# INFO:root:
# --- 25
# INFO:root:Split dataset. Validation set is 0.25%
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.6328125, 0.390625], [0.8828125, -2.109375], [0.3828125, 2.890625], [0.2578125, -0.859375], [0.7578125, 4.140625]]
# INFO:root:In dataset add 5 new results
# INFO:root:
# --- 26
# INFO:root:Split dataset. Validation set is 0.25%
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.5078125, -3.359375], [0.0078125, 1.640625], [0.01171875, -1.6796875], [0.51171875, 3.3203125], [0.76171875, -4.1796875]]
# INFO:root:In dataset add 5 new results
# INFO:root:
# --- 27
# INFO:root:Split dataset. Validation set is 0.25%
# INFO:root:Prediction from sampling plan
# INFO:root:[[0.26171875, 0.8203125], [0.38671875, -2.9296875], [0.88671875, 2.0703125], [0.63671875, -0.4296875], [0.13671875, 4.5703125]]
# INFO:root:In dataset add 5 new results
#        model name                                         prediction  \
# 0   sampling plan  [[0.5, 0.0], [0.75, -2.5], [0.25, 2.5], [0.375...
# 1   sampling plan  [[0.625, -3.75], [0.125, 1.25], [0.1875, -1.87...
# 2   sampling plan  [[0.4375, 0.625], [0.3125, -3.125], [0.8125, 1...
# 3   sampling plan  [[0.09375, -0.3125], [0.59375, 4.6875], [0.843...
# 4   sampling plan  [[0.96875, 0.9375], [0.71875, -1.5625], [0.218...
# 5   sampling plan  [[0.90625, -0.9375], [0.40625, 4.0625], [0.281...
# 6   sampling plan  [[0.03125, 0.3125], [0.046875, -2.34375], [0.5...
# 7   sampling plan  [[0.421875, -3.59375], [0.921875, 1.40625], [0...
# 8   sampling plan  [[0.734375, 0.78125], [0.984375, -1.71875], [0...
# 9   sampling plan  [[0.609375, -2.96875], [0.109375, 2.03125], [0...
# 10  sampling plan  [[0.328125, 4.84375], [0.453125, -1.40625], [0...
# 11  sampling plan  [[0.140625, -0.78125], [0.640625, 4.21875], [0...
# 12  sampling plan  [[0.765625, 0.46875], [0.515625, -2.03125], [0...
# 13  sampling plan  [[0.7734375, -3.515625], [0.2734375, 1.484375]...
# 14  sampling plan  [[0.1484375, 2.734375], [0.2109375, -2.890625]...
# 15  sampling plan  [[0.3359375, -1.640625], [0.8359375, 3.359375]...
# 16  sampling plan  [[0.6171875, 1.171875], [0.8671875, -1.328125]...
# 17  sampling plan  [[0.7421875, -2.578125], [0.2421875, 2.421875]...
# 18  sampling plan  [[0.4296875, 0.546875], [0.3046875, -3.203125]...
# 19  sampling plan  [[0.0390625, -3.671875], [0.5390625, 1.328125]...
# 20  sampling plan  [[0.9140625, 2.578125], [0.6640625, -4.921875]...
# 21  sampling plan  [[0.9765625, -3.046875], [0.4765625, 1.953125]...
# 22  sampling plan  [[0.1015625, 3.203125], [0.0703125, -1.484375]...
# 23  sampling plan  [[0.4453125, -2.734375], [0.9453125, 2.265625]...
# 24  sampling plan  [[0.6328125, 0.390625], [0.8828125, -2.109375]...
# 25  sampling plan  [[0.5078125, -3.359375], [0.0078125, 1.640625]...
# 26  sampling plan  [[0.26171875, 0.8203125], [0.38671875, -2.9296...
#
#     iteration problem  objectives  feature_dim  hypervolume  ndf_space  \
# 0           1    ZDT4           2            2     1.549151   0.000000
# 1           2    ZDT4           2            2     3.856712   0.270912
# 2           3    ZDT4           2            2     4.349524   0.189981
# 3           4    ZDT4           2            2     3.973376   0.215555
# 4           5    ZDT4           2            2     4.055311   0.348803
# 5           6    ZDT4           2            2     4.055311   0.348803
# 6           7    ZDT4           2            2     3.328517   0.452692
# 7           8    ZDT4           2            2     3.328517   0.452692
# 8           9    ZDT4           2            2     3.420862   0.264811
# 9          10    ZDT4           2            2     2.003136   0.302104
# 10         11    ZDT4           2            2     2.003136   0.302104
# 11         12    ZDT4           2            2     2.003136   0.302104
# 12         13    ZDT4           2            2     0.597680   0.330866
# 13         14    ZDT4           2            2     0.597680   0.330866
# 14         15    ZDT4           2            2     0.597680   0.330866
# 15         16    ZDT4           2            2     0.597680   0.330866
# 16         17    ZDT4           2            2     0.597680   0.330866
# 17         18    ZDT4           2            2     0.597680   0.330866
# 18         19    ZDT4           2            2     0.597680   0.330866
# 19         20    ZDT4           2            2     0.597680   0.330866
# 20         21    ZDT4           2            2     0.597680   0.330866
# 21         22    ZDT4           2            2     0.597680   0.330866
# 22         23    ZDT4           2            2     0.669671   0.534236
# 23         24    ZDT4           2            2     0.669671   0.534236
# 24         25    ZDT4           2            2     0.669671   0.534236
# 25         26    ZDT4           2            2     0.709708   0.321690
# 26         27    ZDT4           2            2     0.709708   0.321690
#
#         i_time         tutor_id
# 0     0.008301  140117148792368
# 1     0.027087  140117148792368
# 2     6.676274  140117148792368
# 3    13.529975  140117148792368
# 4    22.996670  140117148792368
# 5    29.614871  140117148792368
# 6    36.285977  140117148792368
# 7    46.057299  140117148792368
# 8    63.187380  140117148792368
# 9    73.605519  140117148792368
# 10   86.597193  140117148792368
# 11   96.735399  140117148792368
# 12  108.161038  140117148792368
# 13  119.038876  140117148792368
# 14  130.653650  140117148792368
# 15  139.319075  140117148792368
# 16  152.222180  140117148792368
# 17  160.671083  140117148792368
# 18  174.721587  140117148792368
# 19  191.712466  140117148792368
# 20  201.817828  140117148792368
# 21  212.447209  140117148792368
# 22  223.001028  140117148792368
# 23  235.100877  140117148792368
# 24  246.403903  140117148792368
# 25  258.357293  140117148792368
# 26  270.933787  140117148792368

# %%
X, y = gen.return_X_y()
y
# Out:
#            f1         f2
# 0    0.500000   0.292893
# 1    0.750000   4.918155
# 2    0.250000   5.903709
# 3    0.375000  19.653731
# 4    0.875000  29.523575
# ..        ...        ...
# 130  0.261719  15.845361
# 131  0.386719  10.976434
# 132  0.886719   6.126365
# 133  0.636719   3.085089
# 134  0.136719  23.675049
#
# [135 rows x 2 columns]

# %%
tutor.cv_result
# Out:
#    fit_time  score_time                                          estimator  \
# 0  3.191019    0.001462  GaussianProcessRegressor(alpha=0, copy_X_train...
# 1  3.635480    0.001471  GaussianProcessRegressor(alpha=0, copy_X_train...
# 2  1.759893    0.001328  GaussianProcessRegressor(alpha=0, copy_X_train...
# 3  2.213628    0.001383  GaussianProcessRegressor(alpha=0, copy_X_train...
# 0  0.174716    0.001196  ([DecisionTreeRegressor(ccp_alpha=0.0, criteri...
# 1  0.078107    0.001592  ([DecisionTreeRegressor(ccp_alpha=0.0, criteri...
# 2  0.108764    0.001817  ([DecisionTreeRegressor(ccp_alpha=0.0, criteri...
# 3  0.196620    0.002105  ([DecisionTreeRegressor(ccp_alpha=0.0, criteri...
# 0  0.246496    0.001686  ([DecisionTreeRegressor(ccp_alpha=0.0, criteri...
# 1  0.184969    0.001966  ([DecisionTreeRegressor(ccp_alpha=0.0, criteri...
# 2  0.210436    0.002225  ([DecisionTreeRegressor(ccp_alpha=0.0, criteri...
# 3  0.147699    0.001913  ([DecisionTreeRegressor(ccp_alpha=0.0, criteri...
#
#     test_r2  test_explained_variance  test_neg_mean_squared_error  \
# 0  0.380011                 0.384251                   -26.870762
# 1  0.621443                 0.633196                   -19.083019
# 2  0.678138                 0.687959                   -32.669067
# 3  0.569746                 0.614247                   -22.996938
# 0  0.998799                 0.999172                    -0.000088
# 1  0.998200                 0.998423                    -0.000155
# 2  0.999104                 0.999403                    -0.000070
# 3  0.998261                 0.998397                    -0.000160
# 0 -0.549619                -0.453168                   -81.506800
# 1  0.076524                 0.194697                   -65.349433
# 2  0.329077                 0.355674                   -87.919053
# 3 -0.006639                 0.025036                   -73.370445
#
#    test_neg_mean_absolute_error y_index                 model name  \
# 0                     -3.287422     all   gaussianprocessregressor
# 1                     -2.729999     all   gaussianprocessregressor
# 2                     -3.605509     all   gaussianprocessregressor
# 3                     -3.170734     all   gaussianprocessregressor
# 0                     -0.008907       0  gradientboostingregressor
# 1                     -0.010851       0  gradientboostingregressor
# 2                     -0.008013       0  gradientboostingregressor
# 3                     -0.011118       0  gradientboostingregressor
# 0                     -7.831932       1  gradientboostingregressor
# 1                     -6.664972       1  gradientboostingregressor
# 2                     -8.681474       1  gradientboostingregressor
# 3                     -7.379815       1  gradientboostingregressor
#
#   params hash      id
# 0        0570  b7b97c
# 1        0570  b7b97c
# 2        0570  b7b97c
# 3        0570  b7b97c
# 0        e3a4  d4a5e6
# 1        e3a4  d4a5e6
# 2        e3a4  d4a5e6
# 3        e3a4  d4a5e6
# 0        e3a4  d4a5e6
# 1        e3a4  d4a5e6
# 2        e3a4  d4a5e6
# 3        e3a4  d4a5e6

# %%
pd.read_csv("/home/valavanca/Documents/hal/Diploma/src/benchmark_results/mtutor_on_zdt_i2.0gr0nsh1ju.csv")
# Out:
#   problem_name  seed  problem_id  objectives  feature_dim  eval_budget  \
# 0          zdt    42           1           2            2           30
# 1          zdt    42           6           2            2           30
#
#                                       surr_portfolio  \
# 0  [GaussianProcessRegressor(alpha=0, copy_X_trai...
# 1  [GaussianProcessRegressor(alpha=0, copy_X_trai...
#
#                                            pop_ndf_x  \
# 0  [[1.70520605e-06 7.48400841e-02]\n [6.11246915...
# 1  [[0.61798489 0.00071248]\n [0.08268763 0.07715...
#
#                                            pop_ndf_f  fevals  evolve_time  \
# 0  [[1.70520605e-06 1.67187145e+00]\n [6.11246915...      27   574.628367
# 1  [[0.97882078 2.08256995]\n [0.28193483 5.72954...      27   342.635647
#
#                date  p_distance  hypervolume  ndf_space  ndf_size  error  \
# 0  2020-02-23 19:58    0.047857     0.274839   0.142287        16    NaN
# 1  2020-02-23 20:03    2.692728     3.069383        NaN         3    NaN
#
#    final
# 0   True
# 1   True

# %%
pd.read_csv("/home/valavanca/Documents/hal/Diploma/src/benchmark_results/ZDT2_tutor_loop_27.139973729412880.csv")[['ndf_size', 'hypervolume', 'ndf_space']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-1fec830ef467> in <module>
# ----> 1 pd.read_csv("/home/valavanca/Documents/hal/Diploma/src/benchmark_results/ZDT2_tutor_loop_27.139973729412880.csv")[['ndf_size', 'hypervolume', 'ndf_space']]
#
# ~/anaconda3/envs/brise-env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# ~/anaconda3/envs/brise-env/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# ~/anaconda3/envs/brise-env/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# ~/anaconda3/envs/brise-env/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1183             if not (self.name == "loc" and not raise_missing):
#    1184                 not_found = list(set(key) - set(ax))
# -> 1185                 raise KeyError("{} not in index".format(not_found))
#    1186
#    1187             # we skip the warning on Categorical/Interval
#
# KeyError: "['ndf_size'] not in index"

# %%
udp = pg.zdt(prob_id=1, param=2)
pro = pg.problem(udp)
plot_mo(pro)

# %%
import ipyparallel as ipp

c = ipp.Client()
c.ids
# Out:
# Waiting for connection file: ~/.ipython/profile_default/security/ipcontroller-client.json
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-44-f048e0e00a6b> in <module>
#       1 import ipyparallel as ipp
#       2
# ----> 3 c = ipp.Client()
#       4 c.ids
#
# ~/anaconda3/envs/brise-env/lib/python3.7/site-packages/ipyparallel/client/client.py in __init__(self, url_file, profile, profile_dir, ipython_dir, context, debug, sshserver, sshkey, password, paramiko, timeout, cluster_id, **extra_args)
#     415                         no_file_msg,
#     416                     ])
# --> 417                     raise IOError(msg)
#     418         if url_file is None:
#     419             raise IOError(no_file_msg)
#
# OSError: Connection file '~/.ipython/profile_default/security/ipcontroller-client.json' not found.
# You have attempted to connect to an IPython Cluster but no Controller could be found.
# Please double-check your configuration and ensure that a cluster is running.
